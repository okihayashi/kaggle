# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import sys, os
sys.path.append(os.pardir)

data = pd.read_csv('./train.csv')
data.head(10)
# Out:
#    id  target  ps_ind_01  ps_ind_02_cat  ps_ind_03  ps_ind_04_cat  \
# 0   7       0          2              2          5              1
# 1   9       0          1              1          7              0
# 2  13       0          5              4          9              1
# 3  16       0          0              1          2              0
# 4  17       0          0              2          0              1
# 5  19       0          5              1          4              0
# 6  20       0          2              1          3              1
# 7  22       0          5              1          4              0
# 8  26       0          5              1          3              1
# 9  28       1          1              1          2              0
#
#    ps_ind_05_cat  ps_ind_06_bin  ps_ind_07_bin  ps_ind_08_bin       ...        \
# 0              0              0              1              0       ...
# 1              0              0              0              1       ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 595212 entries, 0 to 595211
# Data columns (total 59 columns):
# id                595212 non-null int64
# target            595212 non-null int64
# ps_ind_01         595212 non-null int64
# ps_ind_02_cat     595212 non-null int64
# ps_ind_03         595212 non-null int64
# ps_ind_04_cat     595212 non-null int64
# ps_ind_05_cat     595212 non-null int64
# ps_ind_06_bin     595212 non-null int64
# ps_ind_07_bin     595212 non-null int64
# ps_ind_08_bin     595212 non-null int64
# ps_ind_09_bin     595212 non-null int64
# ps_ind_10_bin     595212 non-null int64
# ps_ind_11_bin     595212 non-null int64
# ps_ind_12_bin     595212 non-null int64
# ps_ind_13_bin     595212 non-null int64
# ps_ind_14         595212 non-null int64
# ps_ind_15         595212 non-null int64
# ps_ind_16_bin     595212 non-null int64
# ps_ind_17_bin     595212 non-null int64
# ps_ind_18_bin     595212 non-null int64
# ...

# %%
data.describe()
# Out:
#                  id         target      ps_ind_01  ps_ind_02_cat  \
# count  5.952120e+05  595212.000000  595212.000000  595212.000000
# mean   7.438036e+05       0.036448       1.900378       1.358943
# std    4.293678e+05       0.187401       1.983789       0.664594
# min    7.000000e+00       0.000000       0.000000      -1.000000
# 25%    3.719915e+05       0.000000       0.000000       1.000000
# 50%    7.435475e+05       0.000000       1.000000       1.000000
# 75%    1.115549e+06       0.000000       3.000000       2.000000
# max    1.488027e+06       1.000000       7.000000       4.000000
#
#            ps_ind_03  ps_ind_04_cat  ps_ind_05_cat  ps_ind_06_bin  \
# count  595212.000000  595212.000000  595212.000000  595212.000000
# mean        4.423318       0.416794       0.405188       0.393742
# std         2.699902       0.493311       1.350642       0.488579
# min         0.000000      -1.000000      -1.000000       0.000000
# ...

# %%
data_Y_tmp = data['target']
sns.distplot(data_Y_tmp, kde=False, rug=False, bins=10)

# %% [markdown]
# ### NOTE
# As we can see at histogram above, the column "target" has a bool value, one or zero however they are inbalanced. The number of 'one' is quit smaller than the number of 'zero'.
#
# So first of all, count the number of 'one' by `data_Y_tmp.sum()` and pick the same number as 'one' from 'zero' by `data_0_cut = data[data['target']==0].sample(data_Y_tmp.sum())`.
# After that just concatenate these two dataframe to get the target balanced training data.

# %%
#data_X = data.drop('target', axis=1)

data_0_cut = data[data['target']==0].sample(data_Y_tmp.sum())
data_1 = data[data['target']==1]

data_cut = pd.concat([data_0_cut, data_1])
print(data_0_cut.shape)
print(data_1.shape)
print(data_cut.shape)
# Out:
# (21694, 59)
# (21694, 59)
# (43388, 59)

# %%
data_X = data_cut.drop('target', axis=1)
data_Y = data_cut['target']

print(data_X.shape)
print(data_Y.shape)
# Out:
# (43388, 58)
# (43388,)

# %%
from sklearn.model_selection import train_test_split
train_X, test_X, train_Y, test_Y  = train_test_split(data_X, data_Y, test_size=0.1, random_state=0)

print(train_X.shape)
print(test_X.shape)
print(train_Y.shape)
print(test_Y.shape)
# Out:
# (39049, 58)
# (4339, 58)
# (39049,)
# (4339,)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
#from common.boruta_py import BorutaPy

tree = RandomForestClassifier()
#feat_selector = BorutaPy(tree, n_estimators='auto', verbose=2)
#feat_selector.fit(train_X.as_matrix(), train_Y.as_matrix())

tree = tree.fit(train_X, train_Y)
prediction_tree = tree.predict(test_X)

print(accuracy_score(test_Y, prediction_tree))
print(classification_report(test_Y, prediction_tree))
# Out:
# /Users/okihayas/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# 0.5445955289237151
#               precision    recall  f1-score   support
#
#            0       0.54      0.64      0.59      2165
#            1       0.56      0.45      0.50      2174
#
#    micro avg       0.54      0.54      0.54      4339
#    macro avg       0.55      0.54      0.54      4339
# weighted avg       0.55      0.54      0.54      4339

# %% [markdown]
# ## 2nd try
# At the first try, applied under sampling to the data.
# In this try, apply **over** sampling.

# %%
data_X_next = data.drop('target', axis=1)
data_Y_next = data['target']

from imblearn.over_sampling import SMOTE

sm = SMOTE(random_state=42)
X_res, Y_res = sm.fit_sample(data_X_next, data_Y_next)

sns.distplot(Y_res, kde=False, rug=False, bins=10)

# %%
train_X_res, test_X_res, train_Y_res, test_Y_res  = train_test_split(X_res, Y_res, test_size=0.2, random_state=0)


print(train_X_res.shape)
print(test_X_res.shape)
print(train_Y_res.shape)
print(test_Y_res.shape)
# Out:
# (917628, 58)
# (229408, 58)
# (917628,)
# (229408,)

# %%
#from common.boruta_py import BorutaPy

tree2 = RandomForestClassifier(n_estimators=100,random_state=42)
#feat_selector = BorutaPy(tree2, n_estimators='auto', two_step=False, verbose=2, random_state=42)
#feat_selector.fit(train_X_res, train_Y_res)

# %%
tree2 = tree.fit(train_X_res, train_Y_res)

prediction_tree2 = tree2.predict(test_X)

print(accuracy_score(test_Y, prediction_tree2))
print(classification_report(test_Y, prediction_tree2))
# Out:
# 0.7923484673887993
#               precision    recall  f1-score   support
#
#            0       0.71      1.00      0.83      2165
#            1       1.00      0.59      0.74      2174
#
#    micro avg       0.79      0.79      0.79      4339
#    macro avg       0.85      0.79      0.78      4339
# weighted avg       0.85      0.79      0.78      4339

# %%
from sklearn import metrics

fpr, tpr, thresholds = metrics.roc_curve(test_Y, prediction_tree2)
auc = metrics.auc(fpr, tpr)
print(auc)
# Out:
# 0.7985280588776449

# %% [markdown]
# ## 3rd Try
#
# Remove obviously unnecessary column

# %%
data_X_3rd_pre = data.drop('target', axis=1)
unwanted = data_X_3rd_pre.columns[data_X_3rd_pre.columns.str.startswith('ps_calc_')]
data_X_3rd = data_X_3rd_pre.drop(unwanted, axis=1)
test_X_drop = test_X.drop(unwanted, axis=1)

data_Y_3rd = data['target']

from imblearn.over_sampling import SMOTE

sm = SMOTE(random_state=42)
X_res_3rd, Y_res_3rd = sm.fit_sample(data_X_3rd, data_Y_3rd)
print(X_res_3rd.shape)
# Out:
# (1147036, 38)

# %%
train_X_3rd, test_X_3rd, train_Y_3rd, test_Y_3rd  = train_test_split(X_res_3rd, Y_res_3rd, test_size=0.2, random_state=0)


print(train_X_3rd.shape)
print(test_X_3rd.shape)
print(train_Y_3rd.shape)
print(test_Y_3rd.shape)
# Out:
# (917628, 38)
# (229408, 38)
# (917628,)
# (229408,)

# %%
tree3 = RandomForestClassifier(n_estimators=100,random_state=42)

tree3 = tree.fit(train_X_3rd, train_Y_3rd)

prediction_tree3 = tree3.predict(test_X_drop)

print(accuracy_score(test_Y, prediction_tree3))
print(classification_report(test_Y, prediction_tree3))
# Out:
# 0.8011062456787278
#               precision    recall  f1-score   support
#
#            0       0.72      1.00      0.83      2165
#            1       1.00      0.60      0.75      2174
#
#    micro avg       0.80      0.80      0.80      4339
#    macro avg       0.86      0.80      0.79      4339
# weighted avg       0.86      0.80      0.79      4339

# %% [markdown]
# ref https://www.kaggle.com/sudosudoohio/stratified-kfold-xgboost-eda-tutorial-0-281
